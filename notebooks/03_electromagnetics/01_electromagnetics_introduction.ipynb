# %% [raw]
# ---
# title: "EM mapping"
# kernelspec:
#   name: python3
#   display_name: Python 3 (Geophysics)
#   language: python
# ---

# %% [markdown]
# # Introduction to Electromagnetic (EM) mapping
